# %%
import pandas as pd

from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.ensemble import ExtraTreesClassifier

from sklearn.model_selection import cross_validate

# %%
import preprocessor

# %%
dir_path = '../data/'
preprocessor.check_datasets(dir_path, index_col=None, transpose_flag=False)
# Out:
# Total number of files 1

# %%
dataset = pd.read_csv('../data/Soybean_Intensification.csv', index_col=None)
print(dataset.shape)
# Out:
# (49028, 17)

# %%
print(dataset.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49028 entries, 0 to 49027
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         49028 non-null  int64
#  1   County.Code                  49028 non-null  int64
#  2   USDA.agricultural.region     49028 non-null  int64
#  3   Soybean.Yield.(Bu)           49028 non-null  float64
#  4   Soybean.Acres.Planted        49028 non-null  float64
#  5   Soybean.Price.Lag1           49028 non-null  float64
#  6   3year.Expectation            49028 non-null  float64
#  7   Half.Planted.Day             49028 non-null  float64
#  8   Potash.Application.Rate      49028 non-null  float64
#  9   Nitrogen.Application.Rate    49028 non-null  float64
#  10  Phosphate.Application.Rate   49028 non-null  float64
#  11  GM.Uptake                    49028 non-null  float64
# ...

# %%
dataset.describe()
# Out:
#               Year   County.Code  USDA.agricultural.region  \
# count  49028.00000  49028.000000              49028.000000
# mean    2003.50000  29899.287264                  3.234152
# std        8.07783  13309.376951                  1.959343
# min     1990.00000   1001.000000                  1.000000
# 25%     1996.75000  19117.000000                  1.000000
# 50%     2003.50000  29047.000000                  3.000000
# 75%     2010.25000  40031.000000                  5.000000
# max     2017.00000  55141.000000                  6.000000
#
#        Soybean.Yield.(Bu)  Soybean.Acres.Planted  Soybean.Price.Lag1  \
# count        49028.000000           49028.000000        49028.000000
# mean            36.131529           37196.350861            7.466621
# std             11.054962           48724.452113            2.725743
# min              0.674194              50.000000            4.050000
# 25%             28.249378            2200.000000            5.500000
# ...

# %%
corr = dataset.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_0a928_row0_col0, #T_0a928_row1_col1, #T_0a928_row2_col2, #T_0a928_row3_col3, #T_0a928_row4_col4, #T_0a928_row5_col5, #T_0a928_row6_col6, #T_0a928_row7_col7, #T_0a928_row8_col8, #T_0a928_row9_col9, #T_0a928_row10_col10, #T_0a928_row11_col11, #T_0a928_row12_col12, #T_0a928_row13_col13, #T_0a928_row14_col14, #T_0a928_row15_col15, #T_0a928_row16_col16 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_0a928_row0_col1, #T_0a928_row1_col3, #T_0a928_row1_col4, #T_0a928_row15_col3 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_0a928_row0_col2, #T_0a928_row14_col15 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_0a928_row0_col3, #T_0a928_row5_col3, #T_0a928_row6_col13, #T_0a928_row7_col16 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_0a928_row0_col4, #T_0a928_row5_col4, #T_0a928_row8_col12 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_0a928_row0_col5 {
#   background-color: #f5a081;
# ...

# %%
# instantiate Preprocessor class
preprocessor = preprocessor.Preprocessor()

# %%
preprocessor.fit(dataset, False)
features = preprocessor.transform(dataset, False)

# %%
print(features.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49028 entries, 0 to 49027
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         49028 non-null  int64
#  1   County.Code                  49028 non-null  int64
#  2   USDA.agricultural.region     49028 non-null  int64
#  3   Soybean.Yield.(Bu)           49028 non-null  float64
#  4   Soybean.Acres.Planted        49028 non-null  float64
#  5   Soybean.Price.Lag1           49028 non-null  float64
#  6   3year.Expectation            49028 non-null  float64
#  7   Half.Planted.Day             49028 non-null  float64
#  8   Potash.Application.Rate      49028 non-null  float64
#  9   Nitrogen.Application.Rate    49028 non-null  float64
#  10  Phosphate.Application.Rate   49028 non-null  float64
#  11  GM.Uptake                    49028 non-null  float64
# ...

# %%
# dataset.boxplot(figsize=(20,10));
